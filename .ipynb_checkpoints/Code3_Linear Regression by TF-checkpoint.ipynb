# %% [markdown]
# ### TensorFlow实现线性回归：美食评分案例

# %%
import pandas as pd
MasterFile=pd.read_csv('./data/FoodScore.csv') 
print(MasterFile.shape)
MasterFile[0:5]
# Out:
# (196, 2)
#      ID     score
# 0  pic1  2.750333
# 1  pic2  2.962092
# 2  pic3  3.459351
# 3  pic4  2.246845
# 4  pic5  2.609172

# %%
MasterFile.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fecded66c50>]],
#       dtype=object)

# %%
import numpy as np
FileNames=MasterFile['ID']
N=len(FileNames)
Y=np.array(MasterFile['score']).reshape([N,1])
Y=(Y-np.mean(Y))/np.std(Y)

# %%
from PIL import Image

IMSIZE=128
X=np.zeros([N,IMSIZE,IMSIZE,3])
for i in range(N):
    MyFile=FileNames[i]
    Im=Image.open('./data/FoodScore/'+MyFile+'.jpg')
    Im=Im.resize([IMSIZE,IMSIZE])
    Im=np.array(Im)/255
    X[i,]=Im

# %%
from matplotlib import pyplot as plt
plt.figure()
fig,ax=plt.subplots(2,5)
fig.set_figheight(7.5)
fig.set_figwidth(15)
ax=ax.flatten()
for i in range(10):
    ax[i].imshow(X[i,:,:,:])
    ax[i].set_title(np.round(Y[i],2))
# Out:
# /root/miniconda3/envs/myconda/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
###### 由于版本问题，原书稿用的是cross_validation
from sklearn.model_selection import train_test_split
X0,X1,Y0,Y1=train_test_split(X,Y,test_size=0.5,random_state=0)

# %%
from keras.layers import Dense, Flatten, Input
from keras import Model
input_layer=Input([IMSIZE,IMSIZE,3])
x=input_layer
x=Flatten()(x)
x=Dense(1)(x)
output_layer=x
model=Model(input_layer,output_layer)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 128, 128, 3)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 49152)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 49153
# =================================================================
# Total params: 49,153
# Trainable params: 49,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import Adam
model.compile(loss='mse',optimizer=Adam(lr=0.001),metrics=['mse'])

# %%
model.fit(X0,Y0,validation_data=[X1,Y1],batch_size=100,epochs=100)
# Out:
# Train on 98 samples, validate on 98 samples
# Epoch 1/100
# 98/98 [==============================] - 0s 1ms/step - loss: 1.0664 - mse: 1.0664 - val_loss: 570.2142 - val_mse: 570.2142
# Epoch 2/100
# 98/98 [==============================] - 0s 558us/step - loss: 598.7816 - mse: 598.7816 - val_loss: 38.8895 - val_mse: 38.8895
# Epoch 3/100
# 98/98 [==============================] - 0s 657us/step - loss: 39.9747 - mse: 39.9747 - val_loss: 120.2716 - val_mse: 120.2716
# Epoch 4/100
# 98/98 [==============================] - 0s 742us/step - loss: 128.5550 - mse: 128.5550 - val_loss: 323.9397 - val_mse: 323.9397
# Epoch 5/100
# 98/98 [==============================] - 0s 904us/step - loss: 344.8166 - mse: 344.8166 - val_loss: 245.0816 - val_mse: 245.0816
# Epoch 6/100
# 98/98 [==============================] - 0s 572us/step - loss: 261.0918 - mse: 261.0918 - val_loss: 70.5243 - val_mse: 70.5243
# Epoch 7/100
# 98/98 [==============================] - 0s 832us/step - loss: 5.5834 - mse: 5.5834 - val_loss: 3.1127 - val_mse: 3.1127
# Epoch 46/100
# 98/98 [==============================] - 0s 702us/step - loss: 2.7174 - mse: 2.7174 - val_loss: 1.1493 - val_mse: 1.1493
# Epoch 47/100
# 98/98 [==============================] - 0s 641us/step - loss: 0.7017 - mse: 0.7017 - val_loss: 1.8588 - val_mse: 1.8588
# Epoch 48/100
# 98/98 [==============================] - 0s 767us/step - loss: 1.5046 - mse: 1.5046 - val_loss: 3.6566 - val_mse: 3.6566
# Epoch 49/100
# 98/98 [==============================] - 0s 768us/step - loss: 3.4316 - mse: 3.4316 - val_loss: 3.9506 - val_mse: 3.9506
# Epoch 50/100
# 98/98 [==============================] - 0s 585us/step - loss: 3.7356 - mse: 3.7356 - val_loss: 2.4531 - val_mse: 2.4531
# Epoch 51/100
# 98/98 [==============================] - 0s 706us/step - loss: 2.1172 - mse: 2.1172 - val_loss: 1.1594 - val_mse: 1.1594
# Epoch 52/100
# 98/98 [==============================] - 0s 987us/step - loss: 0.6996 - mse: 0.6996 - val_loss: 1.5107 - val_mse: 1.5107
# Epoch 53/100
# 98/98 [==============================] - 0s 960us/step - loss: 1.0233 - mse: 1.0233 - val_loss: 2.6738 - val_mse: 2.6738
# Epoch 54/100
# 98/98 [==============================] - 0s 1ms/step - loss: 2.2216 - mse: 2.2216 - val_loss: 2.9345 - val_mse: 2.9345
# Epoch 55/100
# 98/98 [==============================] - 0s 872us/step - loss: 2.4884 - mse: 2.4884 - val_loss: 2.0006 - val_mse: 2.0006
# Epoch 56/100
# 98/98 [==============================] - 0s 623us/step - loss: 1.5117 - mse: 1.5117 - val_loss: 1.1471 - val_mse: 1.1471
# Epoch 57/100
# 98/98 [==============================] - 0s 445us/step - loss: 0.6292 - mse: 0.6292 - val_loss: 1.3345 - val_mse: 1.3345
# Epoch 58/100
# 98/98 [==============================] - 0s 420us/step - loss: 0.8446 - mse: 0.8446 - val_loss: 2.0262 - val_mse: 2.0262
# Epoch 59/100
# 98/98 [==============================] - 0s 598us/step - loss: 1.5820 - mse: 1.5820 - val_loss: 2.1359 - val_mse: 2.1359
# Epoch 60/100
# 98/98 [==============================] - 0s 699us/step - loss: 1.6906 - mse: 1.6906 - val_loss: 1.5457 - val_mse: 1.5457
# Epoch 61/100
# 98/98 [==============================] - 0s 729us/step - loss: 1.0487 - mse: 1.0487 - val_loss: 1.1012 - val_mse: 1.1012
# Epoch 62/100
# 98/98 [==============================] - 0s 447us/step - loss: 0.5564 - mse: 0.5564 - val_loss: 1.3212 - val_mse: 1.3212
# Epoch 63/100
# 98/98 [==============================] - 0s 414us/step - loss: 0.7692 - mse: 0.7692 - val_loss: 1.7484 - val_mse: 1.7484
# Epoch 64/100
# 98/98 [==============================] - 0s 468us/step - loss: 1.2081 - mse: 1.2081 - val_loss: 1.7221 - val_mse: 1.7221
# Epoch 65/100
# 98/98 [==============================] - 0s 410us/step - loss: 1.1756 - mse: 1.1756 - val_loss: 1.3095 - val_mse: 1.3095
# Epoch 66/100
# 98/98 [==============================] - 0s 395us/step - loss: 0.7401 - mse: 0.7401 - val_loss: 1.0958 - val_mse: 1.0958
# Epoch 67/100
# 98/98 [==============================] - 0s 728us/step - loss: 0.5159 - mse: 0.5159 - val_loss: 1.2948 - val_mse: 1.2948
# Epoch 68/100
# 98/98 [==============================] - 0s 422us/step - loss: 0.7252 - mse: 0.7252 - val_loss: 1.5162 - val_mse: 1.5162
# Epoch 69/100
# 98/98 [==============================] - 0s 380us/step - loss: 0.9542 - mse: 0.9542 - val_loss: 1.4122 - val_mse: 1.4122
# Epoch 70/100
# 98/98 [==============================] - 0s 368us/step - loss: 0.8361 - mse: 0.8361 - val_loss: 1.1589 - val_mse: 1.1589
# Epoch 71/100
# 98/98 [==============================] - 0s 363us/step - loss: 0.5590 - mse: 0.5590 - val_loss: 1.1179 - val_mse: 1.1179
# Epoch 72/100
# 98/98 [==============================] - 0s 394us/step - loss: 0.5070 - mse: 0.5070 - val_loss: 1.2881 - val_mse: 1.2881
# Epoch 73/100
# 98/98 [==============================] - 0s 360us/step - loss: 0.6802 - mse: 0.6802 - val_loss: 1.3670 - val_mse: 1.3670
# Epoch 74/100
# 98/98 [==============================] - 0s 358us/step - loss: 0.7583 - mse: 0.7583 - val_loss: 1.2370 - val_mse: 1.2370
# Epoch 75/100
# 98/98 [==============================] - 0s 359us/step - loss: 0.6159 - mse: 0.6159 - val_loss: 1.1059 - val_mse: 1.1059
# Epoch 76/100
# 98/98 [==============================] - 0s 371us/step - loss: 0.4715 - mse: 0.4715 - val_loss: 1.1496 - val_mse: 1.1496
# Epoch 77/100
# 98/98 [==============================] - 0s 454us/step - loss: 0.5107 - mse: 0.5107 - val_loss: 1.2591 - val_mse: 1.2591
# Epoch 78/100
# 98/98 [==============================] - 0s 456us/step - loss: 0.6191 - mse: 0.6191 - val_loss: 1.2484 - val_mse: 1.2484
# Epoch 79/100
# 98/98 [==============================] - 0s 387us/step - loss: 0.6016 - mse: 0.6016 - val_loss: 1.1428 - val_mse: 1.1428
# Epoch 80/100
# 98/98 [==============================] - 0s 350us/step - loss: 0.4854 - mse: 0.4854 - val_loss: 1.1046 - val_mse: 1.1046
# Epoch 81/100
# 98/98 [==============================] - 0s 361us/step - loss: 0.4421 - mse: 0.4421 - val_loss: 1.1666 - val_mse: 1.1666
# Epoch 82/100
# 98/98 [==============================] - 0s 372us/step - loss: 0.5049 - mse: 0.5049 - val_loss: 1.2057 - val_mse: 1.2057
# Epoch 83/100
# 98/98 [==============================] - 0s 361us/step - loss: 0.5423 - mse: 0.5423 - val_loss: 1.1577 - val_mse: 1.1577
# Epoch 84/100
# 98/98 [==============================] - 0s 358us/step - loss: 0.4852 - mse: 0.4852 - val_loss: 1.1060 - val_mse: 1.1060
# Epoch 85/100
# 98/98 [==============================] - 0s 358us/step - loss: 0.4220 - mse: 0.4220 - val_loss: 1.1279 - val_mse: 1.1279
# Epoch 86/100
# 98/98 [==============================] - 0s 347us/step - loss: 0.4358 - mse: 0.4358 - val_loss: 1.1747 - val_mse: 1.1747
# Epoch 87/100
# 98/98 [==============================] - 0s 358us/step - loss: 0.4772 - mse: 0.4772 - val_loss: 1.1665 - val_mse: 1.1665
# Epoch 88/100
# 98/98 [==============================] - 0s 360us/step - loss: 0.4633 - mse: 0.4633 - val_loss: 1.1209 - val_mse: 1.1209
# Epoch 89/100
# 98/98 [==============================] - 0s 353us/step - loss: 0.4128 - mse: 0.4128 - val_loss: 1.1085 - val_mse: 1.1085
# Epoch 90/100
# 98/98 [==============================] - 0s 372us/step - loss: 0.3990 - mse: 0.3990 - val_loss: 1.1345 - val_mse: 1.1345
# Epoch 91/100
# 98/98 [==============================] - 0s 386us/step - loss: 0.4252 - mse: 0.4252 - val_loss: 1.1439 - val_mse: 1.1439
# Epoch 92/100
# 98/98 [==============================] - 0s 405us/step - loss: 0.4312 - mse: 0.4312 - val_loss: 1.1212 - val_mse: 1.1212
# Epoch 93/100
# 98/98 [==============================] - 0s 414us/step - loss: 0.4002 - mse: 0.4002 - val_loss: 1.1088 - val_mse: 1.1088
# Epoch 94/100
# 98/98 [==============================] - 0s 412us/step - loss: 0.3778 - mse: 0.3778 - val_loss: 1.1275 - val_mse: 1.1275
# Epoch 95/100
# 98/98 [==============================] - 0s 430us/step - loss: 0.3883 - mse: 0.3883 - val_loss: 1.1441 - val_mse: 1.1441
# Epoch 96/100
# 98/98 [==============================] - 0s 426us/step - loss: 0.3989 - mse: 0.3989 - val_loss: 1.1323 - val_mse: 1.1323
# Epoch 97/100
# 98/98 [==============================] - 0s 426us/step - loss: 0.3828 - mse: 0.3828 - val_loss: 1.1132 - val_mse: 1.1132
# Epoch 98/100
# 98/98 [==============================] - 0s 423us/step - loss: 0.3618 - mse: 0.3618 - val_loss: 1.1136 - val_mse: 1.1136
# Epoch 99/100
# 98/98 [==============================] - 0s 419us/step - loss: 0.3621 - mse: 0.3621 - val_loss: 1.1234 - val_mse: 1.1234
# Epoch 100/100
# 98/98 [==============================] - 0s 414us/step - loss: 0.3706 - mse: 0.3706 - val_loss: 1.1211 - val_mse: 1.1211

# %%
MyPic=Image.open('./data/mypic.jpg')
MyPic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x537 at 0x7FEC78121E90>

# %%
MyPic=MyPic.resize((IMSIZE,IMSIZE))        
MyPic=np.array(MyPic)/255                  
MyPic=MyPic.reshape((1,IMSIZE,IMSIZE,3))   
model.predict(MyPic)
# Out:
# array([[-0.09682322]], dtype=float32)
